# %%
#!/usr/bin/env python3
from argparse import ArgumentParser
import numpy as np
import torch
from data import get_dataset, DATASET_CONFIGS
from train import train
from model import MLP
import utils



import matplotlib.pyplot as plt

# %%
task_number = 10
hidden_size=512
hidden_layer_num=2
hidden_dropout_prob=0.5
input_dropout_prob=0.2
lamda=1000

epochs_per_task = 100
batch_size = 128
test_size= 8192
fisher_estimation_sample_size = 2048
lr=1.e-3
weight_decay = 0
eval_log_interval = 250
loss_log_interval= 250
cuda=False

# decide whether to use cuda or not.
cuda = torch.cuda.is_available()

# generate permutations for the tasks.
np.random.seed(0)
permutations = [
    np.random.permutation(DATASET_CONFIGS['mnist']['size']**2) for
    _ in range(task_number)
]

# prepare mnist datasets.
train_datasets = [
    get_dataset('mnist', permutation=p) for p in permutations
]
test_datasets = [
    get_dataset('mnist', train=False, permutation=p) for p in permutations
]

# %%
def loss_plot(x):
    for t, v in x.items():
        plt.plot(list(range((t-1) * epochs_per_task, t * epochs_per_task)), v)

def accuracy_plot(x):
    for t, v in x.items():
        plt.plot(list(range((t-1) * epochs_per_task, task_number * epochs_per_task)), v)
    plt.ylim(0.8, 1)

# %%
def avg_precision_plot(precisions, labels = []): #precisions needs to be in the form of the return value of train
    for num, precision in enumerate(precisions):    
        avg_precisions = []
        total_epochs = task_number*epochs_per_task
        for epoch in range (total_epochs):
            avg_precision = 0
            tasks_considered = epoch // epochs_per_task +1 #gives 1 for first task, 2 for second,...
            for i in range(1,tasks_considered+1): #
                avg_precision += precision[i][epoch - (i-1)*epochs_per_task]
            avg_precision/=tasks_considered
            avg_precisions.append(avg_precision)
        plt.ylim(0.88, 0.94)
        if (len(labels) == len(precisions)):
            plt.plot(range(total_epochs), avg_precisions, label = labels[num])
        else:
            plt.plot(range(total_epochs), avg_precisions)
    plt.legend()

# %%
# prepare the model.
mlp_no_dropout = MLP(
    DATASET_CONFIGS['mnist']['size']**2,
    DATASET_CONFIGS['mnist']['classes'],
    hidden_size,
    hidden_layer_num,
    0,
    0,
    lamda,
)

# initialize the parameters.
utils.gaussian_initialize(mlp_no_dropout)

# prepare the cuda if needed.
if cuda:
    mlp_no_dropout.cuda()

# %%
# run the standard experiment.
consolidate = False
standard_prec_no_dropout, standard_total_loss_no_dropout, standard_ce_loss_no_dropout, standard_ewc_loss_no_dropout = train(
    mlp_no_dropout, train_datasets, test_datasets,
    epochs_per_task,
    batch_size,
    test_size,
    consolidate,
    fisher_estimation_sample_size,
    lr,
    weight_decay,
    eval_log_interval,
    loss_log_interval,
    cuda
)
# Out:
# => task: 1/10 | epoch: 1/100 | progress: [60032/60000] (100%) | prec: 0.08333 | loss => ce: 2.288 / ewc: 0.0 / total: 2.288: : 469it [00:30, 15.16it/s]
# => task: 1/10 | epoch: 2/100 | progress: [60032/60000] (100%) | prec: 0.3854 | loss => ce: 2.227 / ewc: 0.0 / total: 2.227: : 469it [00:29, 16.13it/s]
# => task: 1/10 | epoch: 3/100 | progress: [60032/60000] (100%) | prec: 0.4792 | loss => ce: 2.165 / ewc: 0.0 / total: 2.165: : 469it [00:28, 16.38it/s]
# => task: 1/10 | epoch: 4/100 | progress: [60032/60000] (100%) | prec: 0.6875 | loss => ce: 1.981 / ewc: 0.0 / total: 1.981: : 469it [00:28, 16.41it/s]
# => task: 1/10 | epoch: 5/100 | progress: [60032/60000] (100%) | prec: 0.6562 | loss => ce: 1.781 / ewc: 0.0 / total: 1.781: : 469it [00:28, 16.46it/s]
# => task: 1/10 | epoch: 6/100 | progress: [60032/60000] (100%) | prec: 0.8021 | loss => ce: 1.191 / ewc: 0.0 / total: 1.191: : 469it [00:28, 16.42it/s]
# => task: 1/10 | epoch: 7/100 | progress: [60032/60000] (100%) | prec: 0.8021 | loss => ce: 0.9657 / ewc: 0.0 / total: 0.9657: : 469it [00:28, 16.40it/s]
# => task: 1/10 | epoch: 8/100 | progress: [60032/60000] (100%) | prec: 0.8542 | loss => ce: 0.7061 / ewc: 0.0 / total: 0.7061: : 469it [00:28, 16.28it/s]
# => task: 1/10 | epoch: 9/100 | progress: [60032/60000] (100%) | prec: 0.8021 | loss => ce: 0.8562 / ewc: 0.0 / total: 0.8562: : 469it [00:28, 16.35it/s]
# => task: 1/10 | epoch: 10/100 | progress: [60032/60000] (100%) | prec: 0.8229 | loss => ce: 0.6103 / ewc: 0.0 / total: 0.6103: : 469it [00:28, 16.34it/s]
# => task: 1/10 | epoch: 11/100 | progress: [60032/60000] (100%) | prec: 0.8125 | loss => ce: 0.6441 / ewc: 0.0 / total: 0.6441: : 469it [00:28, 16.30it/s]
# => task: 1/10 | epoch: 12/100 | progress: [60032/60000] (100%) | prec: 0.8854 | loss => ce: 0.4407 / ewc: 0.0 / total: 0.4407: : 469it [00:28, 16.30it/s]
# => task: 1/10 | epoch: 13/100 | progress: [60032/60000] (100%) | prec: 0.8958 | loss => ce: 0.5046 / ewc: 0.0 / total: 0.5046: : 469it [00:28, 16.28it/s]
# => task: 1/10 | epoch: 14/100 | progress: [60032/60000] (100%) | prec: 0.875 | loss => ce: 0.3441 / ewc: 0.0 / total: 0.3441: : 469it [00:28, 16.32it/s]
# => task: 1/10 | epoch: 15/100 | progress: [60032/60000] (100%) | prec: 0.9271 | loss => ce: 0.3477 / ewc: 0.0 / total: 0.3477: : 469it [00:28, 16.26it/s]
# => task: 1/10 | epoch: 16/100 | progress: [60032/60000] (100%) | prec: 0.8646 | loss => ce: 0.3231 / ewc: 0.0 / total: 0.3231: : 469it [00:29, 16.13it/s]
# => task: 1/10 | epoch: 17/100 | progress: [60032/60000] (100%) | prec: 0.8854 | loss => ce: 0.3708 / ewc: 0.0 / total: 0.3708: : 469it [00:28, 16.30it/s]
# => task: 1/10 | epoch: 18/100 | progress: [60032/60000] (100%) | prec: 0.9062 | loss => ce: 0.4546 / ewc: 0.0 / total: 0.4546: : 469it [00:28, 16.31it/s]
# => task: 1/10 | epoch: 19/100 | progress: [60032/60000] (100%) | prec: 0.8854 | loss => ce: 0.4003 / ewc: 0.0 / total: 0.4003: : 469it [00:28, 16.25it/s]
# => task: 1/10 | epoch: 20/100 | progress: [60032/60000] (100%) | prec: 0.875 | loss => ce: 0.3336 / ewc: 0.0 / total: 0.3336: : 469it [00:28, 16.27it/s]
# => task: 1/10 | epoch: 21/100 | progress: [60032/60000] (100%) | prec: 0.9375 | loss => ce: 0.2263 / ewc: 0.0 / total: 0.2263: : 469it [00:29, 15.71it/s]
# => task: 1/10 | epoch: 22/100 | progress: [60032/60000] (100%) | prec: 0.9062 | loss => ce: 0
100 | progress: [60032/60000] (100%) | prec: 0.9583 | loss => ce: 0.2167 / ewc: 0.0 / total: 0.2167: : 469it [00:29, 16.08it/s]
# => task: 1/10 | epoch: 44/100 | progress: [60032/60000] (100%) | prec: 0.9375 | loss => ce: 0.2921 / ewc: 0.0 / total: 0.2921: : 469it [00:31, 15.11it/s]
# => task: 1/10 | epoch: 45/100 | progress: [60032/60000] (100%) | prec: 0.9062 | loss => ce: 0.3377 / ewc: 0.0 / total: 0.3377: : 469it [00:30, 15.46it/s]
# => task: 1/10 | epoch: 46/100 | progress: [60032/60000] (100%) | prec: 0.9375 | loss => ce: 0.3619 / ewc: 0.0 / total: 0.3619: : 469it [00:30, 15.45it/s]
# => task: 1/10 | epoch: 47/100 | progress: [60032/60000] (100%) | prec: 0.8958 | loss => ce: 0.2834 / ewc: 0.0 / total: 0.2834: : 469it [00:30, 15.48it/s]
# => task: 1/10 | epoch: 48/100 | progress: [60032/60000] (100%) | prec: 0.9375 | loss => ce: 0.2417 / ewc: 0.0 / total: 0.2417: : 469it [00:30, 15.47it/s]
# => task: 1/10 | epoch: 49/100 | progress: [60032/60000] (100%) | prec: 0.9167 | loss => ce: 0.2081 / ewc: 0.0 / total: 0.2081: : 469it [00:30, 15.27it/s]
# => task: 1/10 | epoch: 50/100 | progress: [60032/60000] (100%) | prec: 0.9583 | loss => ce: 0.1259 / ewc: 0.0 / total: 0.1259: : 469it [00:32, 14.63it/s]
# => task: 1/10 | epoch: 51/100 | progress: [60032/60000] (100%) | prec: 0.9271 | loss => ce: 0.2666 / ewc: 0.0 / total: 0.2666: : 469it [00:31, 14.87it/s]
# => task: 1/10 | epoch: 52/100 | progress: [60032/60000] (100%) | prec: 0.9271 | loss => ce: 0.32 / ewc: 0.0 / total: 0.32: : 469it [00:30, 15.39it/s]
# => task: 1/10 | epoch: 53/100 | progress: [60032/60000] (100%) | prec: 0.9583 | loss => ce: 0.1664 / ewc: 0.0 / total: 0.1664: : 469it [00:30, 15.39it/s]
# => task: 1/10 | epoch: 54/100 | progress: [60032/60000] (100%) | prec: 0.9896 | loss => ce: 0.09801 / ewc: 0.0 / total: 0.09801: : 469it [00:28, 16.26it/s]
# => task: 1/10 | epoch: 55/100 | progress: [60032/60000] (100%) | prec: 0.9271 | loss => ce: 0.2527 / ewc: 0.0 / total: 0.2527: : 469it [00:28, 16.30it/s]
# => task: 1/10 | epoch: 56/100 | progress: [60032/60000] (100%) | prec: 0.8854 | loss => ce: 0.3338 / ewc: 0.0 / total: 0.3338: : 469it [00:28, 16.27it/s]
# => task: 1/10 | epoch: 57/100 | progress: [60032/60000] (100%) | prec: 0.9479 | loss => ce: 0.1815 / ewc: 0.0 / total: 0.1815: : 469it [00:28, 16.27it/s]
# => task: 1/10 | epoch: 58/100 | progress: [60032/60000] (100%) | prec: 0.9375 | loss => ce: 0.2587 / ewc: 0.0 / total: 0.2587: : 469it [00:28, 16.33it/s]
# => task: 1/10 | epoch: 59/100 | progress: [60032/60000] (100%) | prec: 0.9583 | loss => ce: 0.1914 / ewc: 0.0 / total: 0.1914: : 469it [00:28, 16.28it/s]
# => task: 1/10 | epoch: 60/100 | progress: [60032/60000] (100%) | prec: 0.9271 | loss => ce: 0.1904 / ewc: 0.0 / total: 0.1904: : 469it [00:28, 16.32it/s]
# => task: 1/10 | epoch: 61/100 | progress: [60032/60000] (100%) | prec: 0.9792 | loss => ce: 0.09468 / ewc: 0.0 / total: 0.09468: : 469it [00:28, 16.32it/s]
# => task: 1/10 | epoch: 62/100 | progress: [60032/60000] (100%) | prec: 0.8958 | loss => ce: 0.1936 / ewc: 0.0 / total: 0.1936: : 469it [00:28, 16.31it/s]
# => task: 1/10 | epoch: 63/100 | progress: [60032/60000] (100%) | prec: 0.9167 | loss => ce: 0.2492 / ewc: 0.0 / total: 0.2492: : 469it [00:28, 16.22it/s]
# => task: 1/10 | epoch: 64/100 | progress: [60032/60000] (100%) | prec: 0.9688 | loss => ce: 0.1901 / ewc: 0.0 / total: 0.1901: : 469it [00:28, 16.31it/s]
# => task: 1/10 | epoch: 65/100 | progress: [60032/60000] (100%) | prec: 0.9479 | loss => ce: 0.1614 / ewc: 0.0 / total: 0.1614: : 469it [00:28, 16.36it/s]
# => task: 1/10 | epoch: 66/100 | progress: [60032/60000] (100%) | prec: 0.9479 | loss => ce: 0
100 | progress: [60032/60000] (100%) | prec: 0.9271 | loss => ce: 0.2096 / ewc: 0.0 / total: 0.2096: : 469it [00:31, 15.11it/s]
# => task: 1/10 | epoch: 93/100 | progress: [60032/60000] (100%) | prec: 0.9583 | loss => ce: 0.1096 / ewc: 0.0 / total: 0.1096: : 469it [00:31, 15.10it/s]
# => task: 1/10 | epoch: 94/100 | progress: [60032/60000] (100%) | prec: 0.9479 | loss => ce: 0.177 / ewc: 0.0 / total: 0.177: : 469it [00:31, 15.13it/s]
# => task: 1/10 | epoch: 95/100 | progress: [60032/60000] (100%) | prec: 0.9479 | loss => ce: 0.1308 / ewc: 0.0 / total: 0.1308: : 469it [00:31, 15.12it/s]
# => task: 1/10 | epoch: 96/100 | progress: [60032/60000] (100%) | prec: 0.9583 | loss => ce: 0.1494 / ewc: 0.0 / total: 0.1494: : 469it [00:31, 15.09it/s]
# => task: 1/10 | epoch: 97/100 | progress: [60032/60000] (100%) | prec: 0.9062 | loss => ce: 0.2786 / ewc: 0.0 / total: 0.2786: : 469it [00:31, 14.85it/s]
# => task: 1/10 | epoch: 98/100 | progress: [60032/60000] (100%) | prec: 0.9479 | loss => ce: 0.1628 / ewc: 0.0 / total: 0.1628: : 469it [00:31, 14.87it/s]
# => task: 1/10 | epoch: 99/100 | progress: [60032/60000] (100%) | prec: 0.9688 | loss => ce: 0.06964 / ewc: 0.0 / total: 0.06964: : 469it [00:28, 16.41it/s]
# => task: 1/10 | epoch: 100/100 | progress: [60032/60000] (100%) | prec: 0.9479 | loss => ce: 0.126 / ewc: 0.0 / total: 0.126: : 469it [00:29, 16.17it/s]
# => task: 2/10 | epoch: 1/100 | progress: [60032/60000] (100%) | prec: 0.8021 | loss => ce: 0.6448 / ewc: 0.0 / total: 0.6448: : 469it [00:29, 16.13it/s]
# => task: 2/10 | epoch: 2/100 | progress: [60032/60000] (100%) | prec: 0.8438 | loss => ce: 0.5234 / ewc: 0.0 / total: 0.5234: : 469it [00:28, 16.75it/s]
# => task: 2/10 | epoch: 3/100 | progress: [60032/60000] (100%) | prec: 0.8438 | loss => ce: 0.427 / ewc: 0.0 / total: 0.427: : 469it [00:29, 15.99it/s]
# => task: 2/10 | epoch: 4/100 | progress: [60032/60000] (100%) | prec: 0.9167 | loss => ce: 0.3744 / ewc: 0.0 / total: 0.3744: : 469it [00:30, 15.60it/s]
# => task: 2/10 | epoch: 5/100 | progress: [60032/60000] (100%) | prec: 0.9271 | loss => ce: 0.3005 / ewc: 0.0 / total: 0.3005: : 469it [00:28, 16.33it/s]
# => task: 2/10 | epoch: 6/100 | progress: [60032/60000] (100%) | prec: 0.8542 | loss => ce: 0.5824 / ewc: 0.0 / total: 0.5824: : 469it [00:28, 16.38it/s]
# => task: 2/10 | epoch: 7/100 | progress: [60032/60000] (100%) | prec: 0.8854 | loss => ce: 0.3683 / ewc: 0.0 / total: 0.3683: : 469it [00:29, 15.93it/s]
# => task: 2/10 | epoch: 8/100 | progress: [60032/60000] (100%) | prec: 0.9479 | loss => ce: 0.2826 / ewc: 0.0 / total: 0.2826: : 469it [00:29, 15.67it/s]
# => task: 2/10 | epoch: 9/100 | progress: [60032/60000] (100%) | prec: 0.9062 | loss => ce: 0.3227 / ewc: 0.0 / total: 0.3227: : 469it [00:30, 15.60it/s]
# => task: 2/10 | epoch: 10/100 | progress: [60032/60000] (100%) | prec: 0.9271 | loss => ce: 0.313 / ewc: 0.0 / total: 0.313: : 469it [00:29, 16.07it/s]
# => task: 2/10 | epoch: 11/100 | progress: [60032/60000] (100%) | prec: 0.8646 | loss => ce: 0.3983 / ewc: 0.0 / total: 0.3983: : 469it [00:29, 16.10it/s]
# => task: 2/10 | epoch: 12/100 | progress: [60032/60000] (100%) | prec: 0.9062 | loss => ce: 0.3478 / ewc: 0.0 / total: 0.3478: : 469it [00:28, 16.43it/s]
# => task: 2/10 | epoch: 13/100 | progress: [60032/60000] (100%) | prec: 0.9167 | loss => ce: 0.2281 / ewc: 0.0 / total: 0.2281: : 469it [00:28, 16.46it/s]
# => task: 2/10 | epoch: 14/100 | progress: [60032/60000] (100%) | prec: 0.9062 | loss => ce: 0
100 | progress: [60032/60000] (100%) | prec: 0.9792 | loss => ce: 0.08885 / ewc: 0.0 / total: 0.08885: : 469it [00:27, 17.21it/s]
# => task: 2/10 | epoch: 65/100 | progress: [60032/60000] (100%) | prec: 0.9375 | loss => ce: 0.21 / ewc: 0.0 / total: 0.21: : 469it [00:27, 16.82it/s]
# => task: 2/10 | epoch: 66/100 | progress: [60032/60000] (100%) | prec: 0.9688 | loss => ce: 0.09799 / ewc: 0.0 / total: 0.09799: : 469it [00:27, 16.92it/s]
# => task: 2/10 | epoch: 67/100 | progress: [60032/60000] (100%) | prec: 0.9896 | loss => ce: 0.04825 / ewc: 0.0 / total: 0.04825: : 469it [00:27, 17.13it/s]
# => task: 2/10 | epoch: 68/100 | progress: [60032/60000] (100%) | prec: 0.9688 | loss => ce: 0.1892 / ewc: 0.0 / total: 0.1892: : 469it [00:27, 17.20it/s]
# => task: 2/10 | epoch: 69/100 | progress: [60032/60000] (100%) | prec: 0.9688 | loss => ce: 0.0793 / ewc: 0.0 / total: 0.0793: : 469it [00:27, 17.18it/s]
# => task: 2/10 | epoch: 70/100 | progress: [60032/60000] (100%) | prec: 0.9896 | loss => ce: 0.05739 / ewc: 0.0 / total: 0.05739: : 469it [00:27, 17.15it/s]
# => task: 2/10 | epoch: 71/100 | progress: [60032/60000] (100%) | prec: 0.9896 | loss => ce: 0.06201 / ewc: 0.0 / total: 0.06201: : 469it [00:27, 17.11it/s]
# => task: 2/10 | epoch: 72/100 | progress: [60032/60000] (100%) | prec: 0.9583 | loss => ce: 0.215 / ewc: 0.0 / total: 0.215: : 469it [00:27, 16.76it/s]
# => task: 2/10 | epoch: 73/100 | progress: [60032/60000] (100%) | prec: 0.9792 | loss => ce: 0.07486 / ewc: 0.0 / total: 0.07486: : 469it [00:26, 17.49it/s]
# => task: 2/10 | epoch: 74/100 | progress: [60032/60000] (100%) | prec: 0.9896 | loss => ce: 0.06017 / ewc: 0.0 / total: 0.06017: : 469it [00:26, 17.49it/s]
# => task: 2/10 | epoch: 75/100 | progress: [60032/60000] (100%) | prec: 1.0 | loss => ce: 0.04843 / ewc: 0.0 / total: 0.04843: : 469it [00:26, 17.44it/s]
# => task: 2/10 | epoch: 76/100 | progress: [60032/60000] (100%) | prec: 0.9688 | loss => ce: 0.07276 / ewc: 0.0 / total: 0.07276: : 469it [00:27, 17.32it/s]
# => task: 2/10 | epoch: 77/100 | progress: [60032/60000] (100%) | prec: 0.9896 | loss => ce: 0.06679 / ewc: 0.0 / total: 0.06679: : 469it [00:27, 17.32it/s]
# => task: 2/10 | epoch: 78/100 | progress: [60032/60000] (100%) | prec: 0.9792 | loss => ce: 0.06766 / ewc: 0.0 / total: 0.06766: : 469it [00:28, 16.65it/s]
# => task: 2/10 | epoch: 79/100 | progress: [60032/60000] (100%) | prec: 1.0 | loss => ce: 0.02276 / ewc: 0.0 / total: 0.02276: : 469it [00:27, 17.19it/s]
# => task: 2/10 | epoch: 80/100 | progress: [60032/60000] (100%) | prec: 1.0 | loss => ce: 0.03012 / ewc: 0.0 / total: 0.03012: : 469it [00:26, 17.63it/s]
# => task: 2/10 | epoch: 81/100 | progress: [60032/60000] (100%) | prec: 0.9896 | loss => ce: 0.06496 / ewc: 0.0 / total: 0.06496: : 469it [00:26, 17.61it/s]
# => task: 2/10 | epoch: 82/100 | progress: [60032/60000] (100%) | prec: 1.0 | loss => ce: 0.03353 / ewc: 0.0 / total: 0.03353: : 469it [00:26, 17.52it/s]
# => task: 2/10 | epoch: 83/100 | progress: [60032/60000] (100%) | prec: 0.9688 | loss => ce: 0.07952 / ewc: 0.0 / total: 0.07952: : 469it [00:26, 17.63it/s]
# => task: 2/10 | epoch: 84/100 | progress: [60032/60000] (100%) | prec: 0.9688 | loss => ce: 0.07596 / ewc: 0.0 / total: 0.07596: : 469it [00:26, 17.60it/s]
# => task: 2/10 | epoch: 85/100 | progress: [60032/60000] (100%) | prec: 0.9792 | loss => ce: 0.1577 / ewc: 0.0 / total: 0.1577: : 469it [00:27, 17.13it/s]
# => task: 2/10 | epoch: 86/100 | progress: [60032/60000] (100%) | prec: 0.9896 | loss => ce: 0.05054 / ewc: 0.0 / total: 0.05054: : 469it [00:27, 16.90it/s]
# => task: 2/10 | epoch: 87/100 | progress: [60032/60000] (100%) | prec: 0.9792 | loss => ce: 0.1161 / ewc: 0.0 / total: 0.1161: : 469it [00:26, 17.40it/s]
# => task: 2/10 | epoch: 88/100 | progress: [60032/60000] (100%) | prec: 0.9792 | loss => ce: 0.05609 / ewc: 0.0 / total: 0.05609: : 469it [00:26, 17.42it/s]
# => task: 2/10 | epoch: 89/100 | progress: [60032/60000] (100%) | prec: 0.9792 | loss => ce: 0.1004 / ewc: 0.0 / total: 0.1004: : 469it [00:26, 17.52it/s]
# => task: 2/10 | epoch: 90/100 | progress: [60032/60000] (100%) | prec: 0.9896 | loss => ce: 0.1192 / ewc: 0.0 / total: 0.1192: : 469it [00:26, 17.48it/s]
# => task: 2/10 | epoch: 91/100 | progress: [60032/60000] (100%) | prec: 1.0 | loss => ce: 0.04998 / ewc: 0.0 / total: 0.04998: : 469it [00:26, 17.54it/s]
# => task: 2/10 | epoch: 92/100 | progress: [60032/60000] (100%) | prec: 0.9583 | loss => ce: 0.1097 / ewc: 0.0 / total: 0.1097: : 469it [00:26, 17.41it/s]
# => task: 2/10 | epoch: 93/100 | progress: [60032/60000] (100%) | prec: 0.9792 | loss => ce: 0.06343 / ewc: 0.0 / total: 0.06343: : 469it [00:26, 17.45it/s]
# => task: 2/10 | epoch: 94/100 | progress: [60032/60000] (100%) | prec: 0.9896 | loss => ce: 0.05493 / ewc: 0.0 / total: 0.05493: : 469it [00:26, 17.51it/s]
# => task: 2/10 | epoch: 95/100 | progress: [60032/60000] (100%) | prec: 0.9792 | loss => ce: 0.09595 / ewc: 0.0 / total: 0.09595: : 469it [00:26, 17.49it/s]
# => task: 2/10 | epoch: 96/100 | progress: [60032/60000] (100%) | prec: 0.9792 | loss => ce: 0.05734 / ewc: 0.0 / total: 0.05734: : 469it [00:26, 17.49it/s]
# => task: 2/10 | epoch: 97/100 | progress: [60032/60000] (100%) | prec: 0.9792 | loss => ce: 0.06095 / ewc: 0.0 / total: 0.06095: : 469it [00:26, 17.46it/s]
# => task: 2/10 | epoch: 98/100 | progress: [60032/60000] (100%) | prec: 0.9896 | loss => ce: 0.05224 / ewc: 0.0 / total: 0.05224: : 469it [00:26, 17.44it/s]
# => task: 2/10 | epoch: 99/100 | progress: [60032/60000] (100%) | prec: 0.9792 | loss => ce: 0.05633 / ewc: 0.0 / total: 0.05633: : 469it [00:26, 17.55it/s]
# => task: 2/10 | epoch: 100/100 | progress: [60032/60000] (100%) | prec: 0.9688 | loss => ce: 0.09576 / ewc: 0.0 / total: 0.09576: : 469it [00:26, 17.56it/s]
# => task: 3/10 | epoch: 1/100 | progress: [60032/60000] (100%) | prec: 0.8646 | loss => ce: 0.3937 / ewc: 0.0 / total: 0.3937: : 469it [00:26, 17.52it/s]
# => task: 3/10 | epoch: 2/100 | progress: [60032/60000] (100%) | prec: 0.9167 | loss => ce: 0.2504 / ewc: 0.0 / total: 0.2504: : 469it [00:26, 17.56it/s]
# => task: 3/10 | epoch: 3/100 | progress: [60032/60000] (100%) | prec: 0.9167 | loss => ce: 0.3256 / ewc: 0.0 / total: 0.3256: : 469it [00:26, 17.62it/s]
# => task: 3/10 | epoch: 4/100 | progress: [20608/60000] (34%) | prec: 0.9297 | loss => ce: 0.3242 / ewc: 0.0 / total: 0.3242: : 161it [00:09, 16.14it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-3292b8de6266> in <module>
#       1 # run the standard experiment.
#       2 consolidate = False
# ----> 3 standard_prec_no_dropout, standard_total_loss_no_dropout, standard_ce_loss_no_dropout, standard_ewc_loss_no_dropout = train(
#       4     mlp_no_dropout, train_datasets, test_datasets,
#       5     epochs_per_task,
#
# ~/Desktop/University-Coding/Masters_thesis/ewc1/train.py in train(model, train_datasets, test_datasets, epochs_per_task, batch_size, test_size, consolidate, fisher_estimation_sample_size, lr, weight_decay, loss_log_interval, eval_log_interval, cuda)
#      40             data_stream = tqdm(enumerate(data_loader, 1))
#      41
# ---> 42             for batch_index, (x, y) in data_stream:
#      43                 # where are we?
#      44                 data_size = len(x)
#
# ~/Library/Python/3.8/lib/python/site-packages/tqdm/std.py in __iter__(self)
#    1164
#    1165         try:
# -> 1166             for obj in iterable:
#    1167                 yield obj
#    1168                 # Update and possibly print the progressbar.
#
# ~/Library/Python/3.8/lib/python/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/Library/Python/3.8/lib/python/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     473     def _next_data(self):
#     474         index = self._next_index()  # may raise StopIteration
# --> 475         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     476         if self._pin_memory:
#     477             data = _utils.pin_memory.pin_memory(data)
#
# ~/Library/Python/3.8/lib/python/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/Library/Python/3.8/lib/python/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/Library/Python/3.8/lib/python/site-packages/torchvision/datasets/mnist.py in __getitem__(self, index)
#     104
#     105         if self.transform is not None:
# --> 106             img = self.transform(img)
#     107
#     108         if self.target_transform is not None:
#
# ~/Library/Python/3.8/lib/python/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      65     def __call__(self, img):
#      66         for t in self.transforms:
# ---> 67             img = t(img)
#      68         return img
#      69
#
# ~/Library/Python/3.8/lib/python/site-packages/torchvision/transforms/transforms.py in __call__(self, pic)
#     102             Tensor: Converted image.
#     103         """
# --> 104         return F.to_tensor(pic)
#     105
#     106     def __repr__(self):
#
# ~/Library/Python/3.8/lib/python/site-packages/torchvision/transforms/functional.py in to_tensor(pic)
#      94         img = 255 * torch.from_numpy(np.array(pic, np.uint8, copy=False))
#      95     else:
# ---> 96         img = torch.ByteTensor(torch.ByteStorage.from_buffer(pic.tobytes()))
#      97
#      98     img = img.view(pic.size[1], pic.size[0], len(pic.getbands()))
#
# KeyboardInterrupt:

# %%
loss_plot(standard_total_loss_no_dropout)

# %%
accuracy_plot(standard_prec_no_dropout)

# %%
avg_precision_plot([standard_prec_no_dropout])

# %%
lamda = 400
mlp_consolidation_no_dropout = MLP(
    DATASET_CONFIGS['mnist']['size']**2,
    DATASET_CONFIGS['mnist']['classes'],
    hidden_size,
    hidden_layer_num,
    0,
    0,
    lamda,
)
torch.autograd.set_detect_anomaly(True)

utils.gaussian_initialize(mlp_consolidation_no_dropout)

# run the standard experiment.
consolidate = True
ewc_prec_no_dropout, ewc_total_loss_no_dropout, ewc_ce_loss_no_dropout, ewc_ewc_loss_no_dropout =train(
    mlp_consolidation_no_dropout, train_datasets, test_datasets,
    epochs_per_task,
    batch_size,
    test_size,
    consolidate,
    fisher_estimation_sample_size,
    lr,
    weight_decay,
    eval_log_interval,
    loss_log_interval,
    cuda
)

# %%
loss_plot(ewc_total_loss_no_dropout)

# %%
accuracy_plot(ewc_prec_no_dropout)

# %%
avg_precision_plot([ewc_prec_no_dropout])

# %%
# prepare the model.
mlp_dropout = MLP(
    DATASET_CONFIGS['mnist']['size']**2,
    DATASET_CONFIGS['mnist']['classes'],
    hidden_size,
    hidden_layer_num,
    hidden_dropout_prob,
    input_dropout_prob,
    lamda,
)
#different to xavier intialisation ??? test
# initialize the parameters.
utils.gaussian_initialize(mlp_dropout)

# prepare the cuda if needed.
if cuda:
    mlp.cuda()

# %%
# run the standard experiment.
consolidate = False
standard_prec_dropout, standard_total_loss_dropout, standard_ce_loss_dropout, standard_ewc_loss_dropout = train(
    mlp_dropout, train_datasets, test_datasets,
    epochs_per_task,
    batch_size,
    test_size,
    consolidate,
    fisher_estimation_sample_size,
    lr,
    weight_decay,
    eval_log_interval,
    loss_log_interval,
    cuda
)

# %%
loss_plot(standard_total_loss_dropout)

# %%
accuracy_plot(standard_prec_dropout)

# %%
avg_precision_plot([standard_prec_dropout])

# %%
mlp_consolidation_dropout = MLP(
    DATASET_CONFIGS['mnist']['size']**2,
    DATASET_CONFIGS['mnist']['classes'],
    hidden_size,
    hidden_layer_num,
    hidden_dropout_prob,
    input_dropout_prob,
    lamda,
)

utils.gaussian_initialize(mlp_consolidation_dropout)

# run the standard experiment.
consolidate = True
ewc_prec_dropout, ewc_total_loss_dropout, ewc_ce_loss_dropout, ewc_ewc_loss_dropout =train(
    mlp_consolidation_dropout, train_datasets, test_datasets,
    epochs_per_task,
    batch_size,
    test_size,
    consolidate,
    fisher_estimation_sample_size,
    lr,
    weight_decay,
    eval_log_interval,
    loss_log_interval,
    cuda
)

# %%
loss_plot(ewc_total_loss_dropout)

# %%
accuracy_plot(ewc_prec_dropout)

# %%
avg_precision_plot([ewc_prec_dropout])

# %%
avg_precision_plot([standard_prec_no_dropout,ewc_prec, standard_prec,  ewc_prec_dropout], ["no dropout", "dropout", "ewc_40", "ewc_100"])

# %%
'''lamda = 1000
mlp_consolidation_1000 = MLP(
    DATASET_CONFIGS['mnist']['size']**2,
    DATASET_CONFIGS['mnist']['classes'],
    hidden_size,
    hidden_layer_num,
    hidden_dropout_prob,
    input_dropout_prob,
    lamda,
)

# run the standard experiment.
consolidate = True
ewc_prec_1000, ewc_total_loss_1000, ewc_ce_loss_1000, ewc_ewc_loss_1000 =train(
    mlp_consolidation_1000, train_datasets, test_datasets,
    epochs_per_task,
    batch_size,
    test_size,
    consolidate,
    fisher_estimation_sample_size,
    lr,
    weight_decay,
    eval_log_interval,
    loss_log_interval,
    cuda
)'''

# %%
#loss_plot(ewc_total_loss_1000)

# %%
#accuracy_plot(ewc_prec_1000)

# %%
'''lamda = 10
mlp_consolidation_10 = MLP(
    DATASET_CONFIGS['mnist']['size']**2,
    DATASET_CONFIGS['mnist']['classes'],
    hidden_size,
    hidden_layer_num,
    hidden_dropout_prob,
    input_dropout_prob,
    lamda,
)

# run the standard experiment.
consolidate = True
ewc_prec_10, ewc_total_loss_10, ewc_ce_loss_10, ewc_ewc_loss_10 =train(
    mlp_consolidation_10, train_datasets, test_datasets,
    epochs_per_task,
    batch_size,
    test_size,
    consolidate,
    fisher_estimation_sample_size,
    lr,
    weight_decay,
    eval_log_interval,
    loss_log_interval,
    cuda
)'''

# %%
#loss_plot(ewc_total_loss_10)

# %%
#accuracy_plot(ewc_prec_10)

# %%
'''lamda = 80
mlp_consolidation_80 = MLP(
    DATASET_CONFIGS['mnist']['size']**2,
    DATASET_CONFIGS['mnist']['classes'],
    hidden_size,
    hidden_layer_num,
    hidden_dropout_prob,
    input_dropout_prob,
    lamda,
)

# run the standard experiment.
consolidate = True
ewc_prec_80, ewc_total_loss_80, ewc_ce_loss_80, ewc_ewc_loss_80 =train(
    mlp_consolidation_80, train_datasets, test_datasets,
    epochs_per_task,
    batch_size,
    test_size,
    consolidate,
    fisher_estimation_sample_size,
    lr,
    weight_decay,
    eval_log_interval,
    loss_log_interval,
    cuda
)'''

# %%
#loss_plot(ewc_total_loss_80)

# %%
#accuracy_plot(ewc_prec_80)
